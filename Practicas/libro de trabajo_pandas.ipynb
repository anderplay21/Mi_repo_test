# %%
#importacion de pandas
import pandas as pd

# %%
#Carga de datos desde CSV a un data frame
df=pd.read_csv('Cancelaciones.csv')

# %%
#informacion de los datos
print(df.head())
print(df.info())

# %%
#Carga de datos desde una Serie
data = [10,20,30,40,50]
s = pd.Series(data)

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
