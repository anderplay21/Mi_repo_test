# %% [markdown]
# Importar las libreria necesarias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Crear el dataframe

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# %%
print(df['B'])
# Out:
# 0    4
# 1    5
# 2    6
# Name: B, dtype: int64
